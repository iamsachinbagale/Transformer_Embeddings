# %% [markdown]
# <a href="https://colab.research.google.com/github/iamsachinbagale/Transformer_Embeddings/blob/main/UMAP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install umap-learn matplotlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.7/85.7 kB 2.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.8/56.8 kB 6.5 MB/s eta 0:00:00
# ...

# %%
import numpy as np
import pandas as pd
import umap
import matplotlib.pyplot as plt
from sklearn.datasets import load_digits

# Load sample data
digits = load_digits()
data = digits.data
labels = digits.target

# Create a DataFrame
df = pd.DataFrame(data)
df['label'] = labels

# %%
# Initialize UMAP with desired parameters
umap_reducer = umap.UMAP(n_neighbors=15, min_dist=0.1, n_components=2, random_state=42)

# Fit and transform the data
embedding = umap_reducer.fit_transform(data)

# Add embeddings to the DataFrame for plotting
df['x'] = embedding[:, 0]
df['y'] = embedding[:, 1]
# Out:
# /usr/local/lib/python3.10/dist-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")

# %%
# Plot the UMAP embeddings
plt.figure(figsize=(10, 8))
scatter = plt.scatter(df['x'], df['y'], c=df['label'], cmap='Spectral', s=5)
plt.colorbar(scatter, label='Digit Label')
plt.title('UMAP Projection of the Digits Dataset')
plt.xlabel('UMAP 1')
plt.ylabel('UMAP 2')
plt.show()
